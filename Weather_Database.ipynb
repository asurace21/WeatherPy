# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | los llanos de aridane
# Processing Record 2 of Set 1 | mahon
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | belaya gora
# Processing Record 6 of Set 1 | ahipara
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | mount isa
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | presidencia roque saenz pena
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | bathsheba
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | naze
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | khasan
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | hay river
# Processing Record 26 of Set 1 | carbondale
# Processing Record 27 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | yumen
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | port blair
# Processing Record 35 of Set 1 | adra
# Processing Record 36 of Set 1 | pontianak
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | patrocinio
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | comodoro rivadavia
# Processing Record 44 of Set 1 | zyryanka
# Processing Record 45 of Set 1 | salamiyah
# Processing Record 46 of Set 1 | granville
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | alto araguaia
# Processing Record 50 of Set 1 | kupang
# Processing Record 1 of Set 2 | sivaki
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | martapura
# Processing Record 4 of Set 2 | baghdad
# Processing Record 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | salinopolis
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | adre
# Processing Record 10 of Set 2 | chifeng
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | pasni
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | charcas
# Processing Record 16 of Set 2 | port arthur
# Processing Record 17 of Set 2 | yar-sale
# Processing Record 18 of Set 2 | maraa
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | qaqortoq
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | solnechnyy
# Processing Record 25 of Set 2 | dzhebariki-khaya
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | almaznyy
# Processing Record 28 of Set 2 | grootfontein
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | clyde river
# Processing Record 32 of Set 2 | berlevag
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | asfi
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | san jeronimo
# Processing Record 38 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 2 | boali
# Processing Record 40 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 2 | dunda
# Processing Record 42 of Set 2 | lasa
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | borlange
# City not found. Skipping...
# Processing Record 49 of Set 2 | kroonstad
# Processing Record 50 of Set 2 | winfield
# Processing Record 1 of Set 3 | syava
# Processing Record 2 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | raduzhnyy
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | morondava
# Processing Record 11 of Set 3 | mamakan
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | goderich
# Processing Record 18 of Set 3 | beringovskiy
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | kirakira
# Processing Record 21 of Set 3 | zonguldak
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | shitkino
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | tukrah
# Processing Record 27 of Set 3 | boulder
# Processing Record 28 of Set 3 | rock springs
# Processing Record 29 of Set 3 | svetlaya
# Processing Record 30 of Set 3 | muhos
# Processing Record 31 of Set 3 | daru
# Processing Record 32 of Set 3 | chardara
# Processing Record 33 of Set 3 | zhuhai
# Processing Record 34 of Set 3 | sabratah
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | volga
# Processing Record 38 of Set 3 | montepuez
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | suntar
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | tagusao
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | opuwo
# Processing Record 47 of Set 3 | fortuna
# Processing Record 48 of Set 3 | nazareno
# Processing Record 49 of Set 3 | sinnamary
# Processing Record 50 of Set 3 | pizarro
# Processing Record 1 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 4 | itaocara
# Processing Record 3 of Set 4 | fenoarivo atsinanana
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | mpulungu
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | bubaque
# Processing Record 11 of Set 4 | tiarei
# Processing Record 12 of Set 4 | lugovoy
# Processing Record 13 of Set 4 | wanning
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | sobolevo
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | khorixas
# Processing Record 18 of Set 4 | ouadda
# Processing Record 19 of Set 4 | bondo
# Processing Record 20 of Set 4 | deputatskiy
# Processing Record 21 of Set 4 | rio verde de mato grosso
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | nelson bay
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | simpang
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | muswellbrook
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | sibolga
# Processing Record 30 of Set 4 | tahoua
# Processing Record 31 of Set 4 | natchitoches
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | port alfred
# Processing Record 34 of Set 4 | uyuni
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | maryborough
# Processing Record 37 of Set 4 | bilibino
# Processing Record 38 of Set 4 | kahului
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | broken hill
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | tuy hoa
# Processing Record 43 of Set 4 | dwarka
# Processing Record 44 of Set 4 | inhambane
# Processing Record 45 of Set 4 | atuona
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | san quintin
# Processing Record 49 of Set 4 | maceio
# Processing Record 50 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 5 | bengkulu
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | hobart
# Processing Record 4 of Set 5 | erdaojiang
# Processing Record 5 of Set 5 | lalmohan
# Processing Record 6 of Set 5 | pisco
# Processing Record 7 of Set 5 | koosa
# Processing Record 8 of Set 5 | kjollefjord
# Processing Record 9 of Set 5 | sioux lookout
# Processing Record 10 of Set 5 | hofn
# Processing Record 11 of Set 5 | kalmunai
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | vaini
# Processing Record 14 of Set 5 | ayan
# Processing Record 15 of Set 5 | havre-saint-pierre
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | fez
# Processing Record 18 of Set 5 | aden
# Processing Record 19 of Set 5 | hit
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | soacha
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | linhares
# Processing Record 24 of Set 5 | hindley
# Processing Record 25 of Set 5 | banihal
# Processing Record 26 of Set 5 | vega de alatorre
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | nadapuram
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | talakan
# Processing Record 31 of Set 5 | iquique
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | sabzevar
# Processing Record 34 of Set 5 | gurjaani
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | taltal
# Processing Record 37 of Set 5 | arlit
# Processing Record 38 of Set 5 | aksarka
# Processing Record 39 of Set 5 | calama
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | hobyo
# Processing Record 42 of Set 5 | istisu
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | tabou
# Processing Record 45 of Set 5 | ruzomberok
# Processing Record 46 of Set 5 | la asuncion
# Processing Record 47 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 5 | takanabe
# Processing Record 49 of Set 5 | valladolid
# Processing Record 50 of Set 5 | havelock
# Processing Record 1 of Set 6 | vanimo
# Processing Record 2 of Set 6 | olafsvik
# Processing Record 3 of Set 6 | shingu
# Processing Record 4 of Set 6 | bukoba
# Processing Record 5 of Set 6 | genthin
# Processing Record 6 of Set 6 | coihaique
# Processing Record 7 of Set 6 | salalah
# Processing Record 8 of Set 6 | atar
# Processing Record 9 of Set 6 | williams lake
# Processing Record 10 of Set 6 | banjar
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | ambovombe
# Processing Record 13 of Set 6 | mar del plata
# Processing Record 14 of Set 6 | zambezi
# Processing Record 15 of Set 6 | yeppoon
# Processing Record 16 of Set 6 | poli
# Processing Record 17 of Set 6 | yatou
# Processing Record 18 of Set 6 | tiksi
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | podgornoye
# Processing Record 21 of Set 6 | la ronge
# Processing Record 22 of Set 6 | vallenar
# Processing Record 23 of Set 6 | tezu
# Processing Record 24 of Set 6 | vanavara
# Processing Record 25 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 6 | porto nacional
# Processing Record 27 of Set 6 | sitka
# Processing Record 28 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 29 of Set 6 | cockburn town
# Processing Record 30 of Set 6 | vedaranniyam
# City not found. Skipping...
# Processing Record 31 of Set 6 | linjiang
# Processing Record 32 of Set 6 | isabela
# Processing Record 33 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 6 | alofi
# Processing Record 35 of Set 6 | blackwater
# Processing Record 36 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | ballina
# Processing Record 41 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 6 | linfen
# Processing Record 43 of Set 6 | koslan
# Processing Record 44 of Set 6 | mandalgovi
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | zhangjiakou
# Processing Record 47 of Set 6 | lumding
# Processing Record 48 of Set 6 | khash
# Processing Record 49 of Set 6 | catabola
# Processing Record 50 of Set 6 | mogadishu
# Processing Record 1 of Set 7 | zhicheng
# Processing Record 2 of Set 7 | cezieni
# Processing Record 3 of Set 7 | wamba
# Processing Record 4 of Set 7 | pavilosta
# Processing Record 5 of Set 7 | leh
# Processing Record 6 of Set 7 | samfya
# Processing Record 7 of Set 7 | cuamba
# Processing Record 8 of Set 7 | saa
# Processing Record 9 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | lacaron
# Processing Record 14 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 7 | uspenka
# Processing Record 16 of Set 7 | vuktyl
# Processing Record 17 of Set 7 | nishihara
# Processing Record 18 of Set 7 | courtalam
# City not found. Skipping...
# Processing Record 19 of Set 7 | bjaeverskov
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | nantucket
# Processing Record 22 of Set 7 | alyangula
# Processing Record 23 of Set 7 | raudeberg
# Processing Record 24 of Set 7 | kapaa
# Processing Record 25 of Set 7 | porosozero
# Processing Record 26 of Set 7 | saint-joseph
# Processing Record 27 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 7 | erenhot
# Processing Record 30 of Set 7 | koster
# Processing Record 31 of Set 7 | khed
# Processing Record 32 of Set 7 | necochea
# Processing Record 33 of Set 7 | ochamchira
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | chase
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | bako
# Processing Record 38 of Set 7 | malkangiri
# Processing Record 39 of Set 7 | oktyabrskoye
# Processing Record 40 of Set 7 | gamba
# Processing Record 41 of Set 7 | agutaya
# Processing Record 42 of Set 7 | tambo
# Processing Record 43 of Set 7 | mastic
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | roma
# Processing Record 46 of Set 7 | tawang
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | navapur
# City not found. Skipping...
# Processing Record 49 of Set 7 | tirat karmel
# Processing Record 50 of Set 7 | sambava
# Processing Record 1 of Set 8 | aljezur
# Processing Record 2 of Set 8 | santa marta
# Processing Record 3 of Set 8 | algiers
# Processing Record 4 of Set 8 | nuqui
# Processing Record 5 of Set 8 | sisimiut
# Processing Record 6 of Set 8 | honggang
# Processing Record 7 of Set 8 | svolvaer
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | port macquarie
# Processing Record 10 of Set 8 | ngora
# Processing Record 11 of Set 8 | gopalpur
# Processing Record 12 of Set 8 | lagos
# Processing Record 13 of Set 8 | alakurtti
# Processing Record 14 of Set 8 | saint anthony
# Processing Record 15 of Set 8 | fort myers beach
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | concepcion del uruguay
# Processing Record 18 of Set 8 | clevedon
# Processing Record 19 of Set 8 | miri
# Processing Record 20 of Set 8 | okha
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 8 | batagay-alyta
# Processing Record 24 of Set 8 | meulaboh
# Processing Record 25 of Set 8 | verkhniye kigi
# Processing Record 26 of Set 8 | poronaysk
# Processing Record 27 of Set 8 | ciudad bolivar
# Processing Record 28 of Set 8 | iraan
# Processing Record 29 of Set 8 | ohafia
# Processing Record 30 of Set 8 | sorong
# Processing Record 31 of Set 8 | tshikapa
# Processing Record 32 of Set 8 | san ignacio
# Processing Record 33 of Set 8 | xuanhua
# Processing Record 34 of Set 8 | yulara
# Processing Record 35 of Set 8 | ojinaga
# Processing Record 36 of Set 8 | nakusp
# Processing Record 37 of Set 8 | gazojak
# Processing Record 38 of Set 8 | bihoro
# Processing Record 39 of Set 8 | honningsvag
# Processing Record 40 of Set 8 | iqaluit
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | talcahuano
# Processing Record 43 of Set 8 | lamu
# Processing Record 44 of Set 8 | asuncion nochixtlan
# Processing Record 45 of Set 8 | cumberland
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | biak
# Processing Record 48 of Set 8 | tonj
# Processing Record 49 of Set 8 | mahibadhoo
# Processing Record 50 of Set 8 | la esperanza
# Processing Record 1 of Set 9 | bemidji
# Processing Record 2 of Set 9 | koumac
# Processing Record 3 of Set 9 | walla walla
# Processing Record 4 of Set 9 | skara
# Processing Record 5 of Set 9 | gunnaur
# Processing Record 6 of Set 9 | sechura
# Processing Record 7 of Set 9 | koidu
# Processing Record 8 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 9 | denizli
# Processing Record 10 of Set 9 | santiago
# Processing Record 11 of Set 9 | baykit
# Processing Record 12 of Set 9 | fort nelson
# Processing Record 13 of Set 9 | sabha
# Processing Record 14 of Set 9 | aswan
# Processing Record 15 of Set 9 | sarvar
# Processing Record 16 of Set 9 | maturin
# Processing Record 17 of Set 9 | kadyy
# Processing Record 18 of Set 9 | cherskiy
# Processing Record 19 of Set 9 | itarema
# Processing Record 20 of Set 9 | tateyama
# Processing Record 21 of Set 9 | grindavik
# Processing Record 22 of Set 9 | kidal
# Processing Record 23 of Set 9 | aykhal
# Processing Record 24 of Set 9 | constitucion
# Processing Record 25 of Set 9 | totskoye
# Processing Record 26 of Set 9 | muzhi
# Processing Record 27 of Set 9 | moryakovskiy zaton
# Processing Record 28 of Set 9 | tres arroyos
# Processing Record 29 of Set 9 | vardo
# Processing Record 30 of Set 9 | liuhe
# Processing Record 31 of Set 9 | ust-shonosha
# Processing Record 32 of Set 9 | wanxian
# Processing Record 33 of Set 9 | edd
# Processing Record 34 of Set 9 | kutum
# Processing Record 35 of Set 9 | pringsewu
# Processing Record 36 of Set 9 | flinders
# Processing Record 37 of Set 9 | marawi
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | lorengau
# Processing Record 42 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | bonavista
# Processing Record 44 of Set 9 | las palmas
# Processing Record 45 of Set 9 | gannan
# Processing Record 46 of Set 9 | emet
# Processing Record 47 of Set 9 | labuan
# Processing Record 48 of Set 9 | cayenne
# Processing Record 49 of Set 9 | bowen
# Processing Record 50 of Set 9 | bay roberts
# Processing Record 1 of Set 10 | maniitsoq
# Processing Record 2 of Set 10 | saint-augustin
# Processing Record 3 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 10 | diego de almagro
# Processing Record 5 of Set 10 | bronnoysund
# Processing Record 6 of Set 10 | harper
# Processing Record 7 of Set 10 | chulman
# Processing Record 8 of Set 10 | makung
# City not found. Skipping...
# Processing Record 9 of Set 10 | suez
# Processing Record 10 of Set 10 | bosaso
# Processing Record 11 of Set 10 | thompson
# Processing Record 12 of Set 10 | margara
# Processing Record 13 of Set 10 | dongsheng
# Processing Record 14 of Set 10 | cotonou
# Processing Record 15 of Set 10 | casma
# Processing Record 16 of Set 10 | ewo
# Processing Record 17 of Set 10 | kommunisticheskiy
# Processing Record 18 of Set 10 | bandarbeyla
# Processing Record 19 of Set 10 | ende
# Processing Record 20 of Set 10 | te anau
# Processing Record 21 of Set 10 | kulu
# Processing Record 22 of Set 10 | taoudenni
# Processing Record 23 of Set 10 | aklavik
# Processing Record 24 of Set 10 | beloyarskiy
# Processing Record 25 of Set 10 | ulladulla
# Processing Record 26 of Set 10 | saint-francois
# Processing Record 27 of Set 10 | saint-leu
# Processing Record 28 of Set 10 | alice springs
# Processing Record 29 of Set 10 | abu dhabi
# Processing Record 30 of Set 10 | kovur
# Processing Record 31 of Set 10 | jamame
# Processing Record 32 of Set 10 | lisakovsk
# Processing Record 33 of Set 10 | san juan
# Processing Record 34 of Set 10 | barcelona
# Processing Record 35 of Set 10 | waipawa
# Processing Record 36 of Set 10 | auki
# Processing Record 37 of Set 10 | zhanakorgan
# Processing Record 38 of Set 10 | alamos
# Processing Record 39 of Set 10 | kunming
# Processing Record 40 of Set 10 | cochrane
# Processing Record 41 of Set 10 | palimbang
# Processing Record 42 of Set 10 | san fernando
# Processing Record 43 of Set 10 | talara
# Processing Record 44 of Set 10 | ankang
# Processing Record 45 of Set 10 | pangnirtung
# Processing Record 46 of Set 10 | cabinda
# Processing Record 47 of Set 10 | jachymov
# Processing Record 48 of Set 10 | victor harbor
# Processing Record 49 of Set 10 | awbari
# Processing Record 50 of Set 10 | joensuu
# Processing Record 1 of Set 11 | portland
# Processing Record 2 of Set 11 | naron
# Processing Record 3 of Set 11 | muravlenko
# Processing Record 4 of Set 11 | luganville
# Processing Record 5 of Set 11 | rondonopolis
# Processing Record 6 of Set 11 | ambon
# Processing Record 7 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 11 | urucara
# Processing Record 9 of Set 11 | arawa
# Processing Record 10 of Set 11 | buraydah
# Processing Record 11 of Set 11 | diamantino
# Processing Record 12 of Set 11 | grammichele
# Processing Record 13 of Set 11 | salisbury
# Processing Record 14 of Set 11 | general roca
# Processing Record 15 of Set 11 | fairbanks
# Processing Record 16 of Set 11 | bonthe
# Processing Record 17 of Set 11 | rocha
# Processing Record 18 of Set 11 | tripoli
# Processing Record 19 of Set 11 | mmathubudukwane
# Processing Record 20 of Set 11 | baoning
# Processing Record 21 of Set 11 | sao felix do xingu
# Processing Record 22 of Set 11 | paita
# Processing Record 23 of Set 11 | hat yai
# Processing Record 24 of Set 11 | beyneu
# Processing Record 25 of Set 11 | jiaocheng
# Processing Record 26 of Set 11 | nanga eboko
# Processing Record 27 of Set 11 | vila velha
# Processing Record 28 of Set 11 | husavik
# Processing Record 29 of Set 11 | padang
# Processing Record 30 of Set 11 | alcudia
# Processing Record 31 of Set 11 | lappeenranta
# Processing Record 32 of Set 11 | san andres
# Processing Record 33 of Set 11 | labuhan
# Processing Record 34 of Set 11 | mezcala
# Processing Record 35 of Set 11 | kayes
# Processing Record 36 of Set 11 | lichinga
# Processing Record 37 of Set 11 | tianpeng
# Processing Record 38 of Set 11 | half moon bay
# Processing Record 39 of Set 11 | vostok
# Processing Record 40 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | magaria
# Processing Record 43 of Set 11 | uthal
# Processing Record 44 of Set 11 | yenagoa
# Processing Record 45 of Set 11 | kulhudhuffushi
# Processing Record 46 of Set 11 | baiao
# Processing Record 47 of Set 11 | derzhavinsk
# Processing Record 48 of Set 11 | sakakah
# Processing Record 49 of Set 11 | honiara
# Processing Record 50 of Set 11 | aktash
# Processing Record 1 of Set 12 | abrau-dyurso
# Processing Record 2 of Set 12 | kruisfontein
# Processing Record 3 of Set 12 | leningradskiy
# Processing Record 4 of Set 12 | chhabra
# Processing Record 5 of Set 12 | nioro
# Processing Record 6 of Set 12 | zaysan
# Processing Record 7 of Set 12 | santa cruz
# Processing Record 8 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 12 | sri aman
# Processing Record 10 of Set 12 | heiligenhafen
# Processing Record 11 of Set 12 | dauriya
# Processing Record 12 of Set 12 | tazmalt
# Processing Record 13 of Set 12 | acapulco
# Processing Record 14 of Set 12 | chimbote
# Processing Record 15 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 12 | codrington
# Processing Record 17 of Set 12 | bac lieu
# Processing Record 18 of Set 12 | vakhrushev
# Processing Record 19 of Set 12 | de-kastri
# Processing Record 20 of Set 12 | jalu
# Processing Record 21 of Set 12 | calvinia
# Processing Record 22 of Set 12 | riyadh
# Processing Record 23 of Set 12 | amatlan
# City not found. Skipping...
# Processing Record 24 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 12 | kloulklubed
# Processing Record 26 of Set 12 | fare
# Processing Record 27 of Set 12 | ixtapa
# Processing Record 28 of Set 12 | perth
# Processing Record 29 of Set 12 | malakal
# Processing Record 30 of Set 12 | sayyan
# Processing Record 31 of Set 12 | luanda
# Processing Record 32 of Set 12 | pirapozinho
# Processing Record 33 of Set 12 | asyut
# Processing Record 34 of Set 12 | kenitra
# Processing Record 35 of Set 12 | kaeo
# Processing Record 36 of Set 12 | la palma
# Processing Record 37 of Set 12 | lamar
# Processing Record 38 of Set 12 | pochutla
# Processing Record 39 of Set 12 | boca do acre
# Processing Record 40 of Set 12 | redmond
# Processing Record 41 of Set 12 | puerto escondido
# Processing Record 42 of Set 12 | vila
# Processing Record 43 of Set 12 | bacolod
# Processing Record 44 of Set 12 | victoria
# Processing Record 45 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 46 of Set 12 | urumqi
# Processing Record 47 of Set 12 | geraldton
# Processing Record 48 of Set 12 | mariental
# Processing Record 49 of Set 12 | boende
# Processing Record 50 of Set 12 | pedernales
# Processing Record 1 of Set 13 | telixtlahuaca
# City not found. Skipping...
# Processing Record 2 of Set 13 | bolu
# Processing Record 3 of Set 13 | ben tre
# Processing Record 4 of Set 13 | berezhany
# Processing Record 5 of Set 13 | qasigiannguit
# Processing Record 6 of Set 13 | zyryanskoye
# Processing Record 7 of Set 13 | lower burrell
# Processing Record 8 of Set 13 | petatlan
# Processing Record 9 of Set 13 | darnah
# Processing Record 10 of Set 13 | santa marinella
# Processing Record 11 of Set 13 | korla
# Processing Record 12 of Set 13 | mattru
# Processing Record 13 of Set 13 | colares
# Processing Record 14 of Set 13 | hami
# Processing Record 15 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 13 | college
# Processing Record 17 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 13 | tyukhtet
# Processing Record 19 of Set 13 | tual
# Processing Record 20 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 13 | orange cove
# Processing Record 22 of Set 13 | tevriz
# Processing Record 23 of Set 13 | port augusta
# Processing Record 24 of Set 13 | konibodom
# Processing Record 25 of Set 13 | adrar
# Processing Record 26 of Set 13 | mecca
# Processing Record 27 of Set 13 | bilma
# Processing Record 28 of Set 13 | amancio
# City not found. Skipping...
# Processing Record 29 of Set 13 | guerrero negro
# Processing Record 30 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 13 | arica
# Processing Record 33 of Set 13 | panaytayon
# Processing Record 34 of Set 13 | balabac
# Processing Record 35 of Set 13 | kathu
# Processing Record 36 of Set 13 | iquitos
# Processing Record 37 of Set 13 | yuxia
# Processing Record 38 of Set 13 | ivanivka
# Processing Record 39 of Set 13 | loandjili
# Processing Record 40 of Set 13 | trairi
# Processing Record 41 of Set 13 | vitim
# Processing Record 42 of Set 13 | krizevci
# Processing Record 43 of Set 13 | warrnambool
# Processing Record 44 of Set 13 | vryburg
# Processing Record 45 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 46 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 47 of Set 13 | nanzhang
# Processing Record 48 of Set 13 | moose factory
# Processing Record 49 of Set 13 | saravan
# Processing Record 50 of Set 13 | loralai
# Processing Record 1 of Set 14 | napanee
# Processing Record 2 of Set 14 | saint-pierre
# Processing Record 3 of Set 14 | san patricio
# Processing Record 4 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 5 of Set 14 | arroyo
# Processing Record 6 of Set 14 | del rio
# Processing Record 7 of Set 14 | severnyy
# Processing Record 8 of Set 14 | katobu
# Processing Record 9 of Set 14 | zorritos
# Processing Record 10 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 14 | lukow
# Processing Record 12 of Set 14 | zhigansk
# Processing Record 13 of Set 14 | wenzhou
# Processing Record 14 of Set 14 | kargasok
# Processing Record 15 of Set 14 | malinovoye ozero
# Processing Record 16 of Set 14 | vung tau
# Processing Record 17 of Set 14 | severobaykalsk
# Processing Record 18 of Set 14 | gizo
# Processing Record 19 of Set 14 | irituia
# Processing Record 20 of Set 14 | kota kinabalu
# Processing Record 21 of Set 14 | chiredzi
# Processing Record 22 of Set 14 | kuusamo
# Processing Record 23 of Set 14 | marshfield
# Processing Record 24 of Set 14 | khuzhir
# Processing Record 25 of Set 14 | blenheim
# Processing Record 26 of Set 14 | sao jose da coroa grande
# Processing Record 27 of Set 14 | basqal
# Processing Record 28 of Set 14 | melilla
# Processing Record 29 of Set 14 | trinidad
# Processing Record 30 of Set 14 | gornyye klyuchi
# Processing Record 31 of Set 14 | nagornskiy
# Processing Record 32 of Set 14 | chegdomyn
# Processing Record 33 of Set 14 | dali
# Processing Record 34 of Set 14 | kungurtug
# Processing Record 35 of Set 14 | raga
# Processing Record 36 of Set 14 | freeport
# Processing Record 37 of Set 14 | lindon
# Processing Record 38 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 39 of Set 14 | lincoln
# Processing Record 40 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 14 | shibetsu
# Processing Record 42 of Set 14 | mayumba
# Processing Record 43 of Set 14 | tashtyp
# Processing Record 44 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 45 of Set 14 | urengoy
# Processing Record 46 of Set 14 | lagunas
# Processing Record 47 of Set 14 | kenai
# Processing Record 48 of Set 14 | sorland
# Processing Record 49 of Set 14 | ridgecrest
# Processing Record 50 of Set 14 | neuquen
# Processing Record 1 of Set 15 | methoni
# Processing Record 2 of Set 15 | sao joao da barra
# Processing Record 3 of Set 15 | flin flon
# Processing Record 4 of Set 15 | san pedro
# Processing Record 5 of Set 15 | kamisu
# Processing Record 6 of Set 15 | dabat
# Processing Record 7 of Set 15 | dovolnoye
# Processing Record 8 of Set 15 | pijijiapan
# Processing Record 9 of Set 15 | bayangol
# Processing Record 10 of Set 15 | dumas
# Processing Record 11 of Set 15 | tchibanga
# Processing Record 12 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 13 of Set 15 | cabo rojo
# Processing Record 14 of Set 15 | carauari
# Processing Record 15 of Set 15 | vestmanna
# Processing Record 16 of Set 15 | makakilo city
# Processing Record 17 of Set 15 | gwadar
# Processing Record 18 of Set 15 | tilichiki
# Processing Record 19 of Set 15 | pando
# Processing Record 20 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 21 of Set 15 | tomatlan
# Processing Record 22 of Set 15 | kamaishi
# Processing Record 23 of Set 15 | salacgriva
# Processing Record 24 of Set 15 | semey
# Processing Record 25 of Set 15 | porto novo
# Processing Record 26 of Set 15 | savannakhet
# Processing Record 27 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 15 | tessalit
# Processing Record 29 of Set 15 | abu kamal
# Processing Record 30 of Set 15 | viedma
# Processing Record 31 of Set 15 | okhotsk
# Processing Record 32 of Set 15 | mariana
# Processing Record 33 of Set 15 | anadyr
# Processing Record 34 of Set 15 | hauterive
# Processing Record 35 of Set 15 | santa cruz do rio pardo
# Processing Record 36 of Set 15 | veinticinco de mayo
# Processing Record 37 of Set 15 | nueva concepcion
# Processing Record 38 of Set 15 | caceres
# Processing Record 39 of Set 15 | petropavlivka
# Processing Record 40 of Set 15 | elat
# Processing Record 41 of Set 15 | millinocket
# Processing Record 42 of Set 15 | silveira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City      Lat       Lng  Max Temp Current Description  \
# 0    Los Llanos De Aridane  28.6585  -17.9182     74.12          few clouds
# 1                    Mahon  39.8885    4.2658     88.36           clear sky
# 2              East London -33.0153   27.9116     67.14           clear sky
# 3                 Tasiilaq  65.6145  -37.6368     50.16     overcast clouds
# 4              Belaya Gora  68.5333  146.4167     44.69           clear sky
# ..                     ...      ...       ...       ...                 ...
# 673                Caceres  39.5220   -6.3748    105.82    scattered clouds
# 674          Petropavlivka  48.4564   36.4367     63.52       broken clouds
# 675                   Elat  29.5581   34.9482     96.64           clear sky
# 676            Millinocket  45.6573  -68.7098     84.31           clear sky
# 677               Silveira  39.1112   -9.3643     80.38           clear sky
#
#      Humidity  Cloudiness  Wind Speed Country
# 0          77          20       17.27      ES
# 1          45           0        5.75      ES
# 2          55           0        5.75      ZA
# 3          78          91        5.99      GL
# 4          64           7        3.89      RU
# ..        ...         ...         ...     ...
# 673         9          45       12.80      ES
# 674        69          71        6.26      UA
# 675        32           0       11.50      IL
# 676        39           0        8.05      US
# 677        79           1        8.99      PT
#
# [678 rows x 9 columns]

# %%
updated_column_format = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",
                    "Current Description"]
city_data_df = city_data_df[updated_column_format]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Los Llanos De Aridane      ES  28.6585  -17.9182     74.12        77
# 1                  Mahon      ES  39.8885    4.2658     88.36        45
# 2            East London      ZA -33.0153   27.9116     67.14        55
# 3               Tasiilaq      GL  65.6145  -37.6368     50.16        78
# 4            Belaya Gora      RU  68.5333  146.4167     44.69        64
# 5                Ahipara      NZ -35.1667  173.1667     48.13        84
# 6                Kavieng      PG  -2.5744  150.7967     81.79        80
# 7                Ushuaia      AR -54.8000  -68.3000     42.46        52
# 8           Saint George      US  37.1041 -113.5841    100.63        23
# 9              Mount Isa      AU -20.7333  139.5000     51.57        76
#
#    Cloudiness  Wind Speed Current Description
# 0          20       17.27          few clouds
# 1           0        5.75           clear sky
# 2           0        5.75           clear sky
# 3          91        5.99     overcast clouds
# 4           7        3.89           clear sky
# 5          91        5.28     overcast clouds
# 6          77       15.37          light rain
# 7          40        5.75    scattered clouds
# 8           0        8.99           clear sky
# 9           2        0.00           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
